# %%
# 1) Imports e configuração básica
import numpy as np
from pathlib import Path
import pandas as pd

# %%
pd.set_option("display.max_columns", 50)
pd.set_option("display.width", 120)

# 2) Caminhos do projeto
PROJECT_ROOT = Path.cwd().parent
DATA_RAW = PROJECT_ROOT / "data"

# 3) Leitura dos CSVs
results = pd.read_csv(DATA_RAW / "results.csv", parse_dates=["date"])
goalscorers = pd.read_csv(DATA_RAW / "goalscorers.csv", parse_dates=["date"])
shootouts = pd.read_csv(DATA_RAW / "shootouts.csv", parse_dates=["date"])

# 4) Checagens rápidas
print("results:", results.shape)
print("goalscorers:", goalscorers.shape)
print("shootouts:", shootouts.shape)

display(results.head(4))
display(goalscorers.head(4))
display(shootouts.head(4))


# 5) Validação mínima de colunas-chave (evita erro lá na frente)
# required_results = {"date", "home_team", "away_team", "home_score", "away_score", "neutral"}
# missing = required_results - set(results.columns)
# if missing:
# raise ValueError(f"results.csv está sem colunas esperadas: {missing}")
# Out:
# results: (44934, 9)
# goalscorers: (41113, 8)
# shootouts: (558, 4)
#         date home_team away_team  home_score  away_score tournament     city   country  neutral
# 0 1872-11-30  Scotland   England           0           0   Friendly  Glasgow  Scotland    False
# 1 1873-03-08   England  Scotland           4           2   Friendly   London   England    False
# 2 1874-03-07  Scotland   England           2           1   Friendly  Glasgow  Scotland    False
# 3 1875-03-06   England  Scotland           2           2   Friendly   London   England    False
#         date home_team away_team     team            scorer  minute  own_goal  penalty
# 0 1916-07-02     Chile   Uruguay  Uruguay   José Piendibene    44.0     False    False
# 1 1916-07-02     Chile   Uruguay  Uruguay  Isabelino Gradín    55.0     False    False
# 2 1916-07-02     Chile   Uruguay  Uruguay  Isabelino Gradín    70.0     False    False
# 3 1916-07-02     Chile   Uruguay  Uruguay   José Piendibene    75.0     False    False
#         date    home_team         away_team       winner
# 0 1967-08-22        India            Taiwan       Taiwan
# 1 1971-11-14  South Korea  Vietnam Republic  South Korea
# 2 1972-05-07  South Korea              Iraq         Iraq
# 3 1972-05-17     Thailand       South Korea  South Korea

# %%
wc = results.query("tournament == 'FIFA World Cup'").copy()

print("Jogos de Copa do Mundo:", wc.shape[0])
print("Copas:", wc["date"].dt.year.unique())
# Out:
# Jogos de Copa do Mundo: 964
# Copas: [1930 1934 1938 1950 1954 1958 1962 1966 1970 1974 1978 1982 1986 1990
#  1994 1998 2002 2006 2010 2014 2018 2022]

# %%
# Diferença absoluta de gols
wc["diff_gols"] = (wc["home_score"] - wc["away_score"]).abs()

# %%
wc["copa"] = wc["date"].dt.year
wc[["date", "copa"]].drop_duplicates().sort_values("copa").head(10)
# Out:
#            date  copa
# 1311 1930-07-13  1930
# 1313 1930-07-14  1930
# 1315 1930-07-15  1930
# 1316 1930-07-16  1930
# 1317 1930-07-17  1930
# 1320 1930-07-18  1930
# 1321 1930-07-19  1930
# 1323 1930-07-20  1930
# 1325 1930-07-21  1930
# 1326 1930-07-22  1930

# %%
baseline = (
    wc.groupby("copa")
      .agg(media_diff=("diff_gols", "mean"))
      .reset_index()
)

display(baseline.round(2))
# Out:
#     copa  media_diff
# 0   1930        2.67
# 1   1934        1.53
# 2   1938        2.11
# 3   1950        2.27
# 4   1954        3.00
# 5   1958        1.54
# 6   1962        1.53
# 7   1966        1.53
# 8   1970        1.53
# 9   1974        1.66
# 10  1978        1.47
# 11  1982        1.38
# 12  1986        1.42
# 13  1990        1.21
# 14  1994        1.37
# 15  1998        1.30
# 16  2002        1.30
# 17  2006        1.42
# 18  2010        1.23
# 19  2014        1.42
# 20  2018        1.30
# 21  2022        1.41

# %%
refino = (
    wc.groupby("copa")
      .agg(
          media_diff=("diff_gols", "mean"),
          mediana_diff=("diff_gols", "median")
      )
      .reset_index()
)

display(refino.round(2))
# Out:
#     copa  media_diff  mediana_diff
# 0   1930        2.67           3.0
# 1   1934        1.53           1.0
# 2   1938        2.11           2.0
# 3   1950        2.27           2.0
# 4   1954        3.00           2.0
# 5   1958        1.54           1.0
# 6   1962        1.53           1.0
# 7   1966        1.53           1.0
# 8   1970        1.53           1.0
# 9   1974        1.66           1.0
# 10  1978        1.47           1.0
# 11  1982        1.38           1.0
# 12  1986        1.42           1.0
# 13  1990        1.21           1.0
# 14  1994        1.37           1.0
# 15  1998        1.30           1.0
# 16  2002        1.30           1.0
# 17  2006        1.42           1.0
# 18  2010        1.23           1.0
# 19  2014        1.42           1.0
# 20  2018        1.30           1.0
# 21  2022        1.41           1.0

# %% [markdown]
# **Mediana = 1 → jogo típico equilibrado**
#
# **Média caindo → menos jogos muito desequilibrados (goleadas)**
#
# Dado que a mediana da diferença de gols se estabiliza em 1, a análise foi complementada com métricas de proporção para avaliar a distribuição dos níveis de equilíbrio das partidas.

# %%
# 1) Categorizar o equilíbrio por diferença de gols
wc["faixa_equilibrio"] = pd.cut(
    wc["diff_gols"],
    bins=[-0.1, 0, 1, 2, np.inf],
    labels=["empate", "1_gol", "2_gols", "3+_gols"]
)

# 2) Contagem por Copa e faixa
counts = (
    wc.groupby(["copa", "faixa_equilibrio"], observed=True)
      .size()
      .rename("jogos_faixa")
      .reset_index()
)

# 3) Percentual dentro de cada Copa
counts["pct"] = counts.groupby("copa")["jogos_faixa"].transform(lambda x: x / x.sum() * 100)

# 4) Pivot para formato final + fillna embutido (remove NaN) + total de jogos
tabela_final = (
    counts.pivot(index="copa", columns="faixa_equilibrio", values="pct")
          .fillna(0.0)   # <- AQUI resolve o NaN de uma vez
          .reset_index()
          .rename_axis(None, axis=1)
)

jogos_por_copa = wc.groupby("copa").size().rename("jogos").reset_index()
tabela_final = tabela_final.merge(jogos_por_copa, on="copa", how="left")

# 5) Ordenar colunas (garante presença de todas)
col_order = ["copa", "jogos", "empate", "1_gol", "2_gols", "3+_gols"]
for c in col_order:
    if c not in tabela_final.columns:
        tabela_final[c] = 0.0

tabela_final = tabela_final[col_order].sort_values("copa")

display(tabela_final.round(2))
# Out:
#     copa  jogos  empate  1_gol  2_gols  3+_gols
# 0   1930     18    0.00  27.78   16.67    55.56
# 1   1934     17    5.88  64.71   17.65    11.76
# 2   1938     18   16.67  27.78   33.33    22.22
# 3   1950     22   13.64  27.27   27.27    31.82
# 4   1954     26    7.69  19.23   30.77    42.31
# 5   1958     35   28.57  28.57   17.14    25.71
# 6   1962     32   15.62  37.50   37.50     9.38
# 7   1966     32   15.62  37.50   34.38    12.50
# 8   1970     32   15.62  43.75   15.62    25.00
# 9   1974     38   26.32  31.58   21.05    21.05
# 10  1978     38   23.68  39.47   21.05    15.79
# 11  1982     52   32.69  32.69   13.46    21.15
# 12  1986     52   26.92  34.62   21.15    17.31
# 13  1990     52   23.08  50.00   15.38    11.54
# 14  1994     52   21.15  46.15   17.31    15.38
# 15  1998     64   29.69  40.62   10.94    18.75
# 16  2002     64   25.00  42.19   21.88    10.94
# 17  2006     64   23.44  32.81   29.69    14.06
# 18  2010     64   25.00  48.44   14.06    12.50
# 19  2014     64   20.31  45.31   15.62    18.75
# 20  2018     64   20.31  48.44   18.75    12.50
# 21  2022     64   23.44  37.50   25.00    14.06

# %%
tabela_final = tabela_final.rename(columns={
    "empate": "% empates",
    "1_gol": "% vitórias por 1 gol",
    "2_gols": "% vitórias por 2 gols",
    "3+_gols": "% vitórias por 3+ gols"
})

display(tabela_final.round(2))
# Out:
#     copa  jogos  % empates  % vitórias por 1 gol  % vitórias por 2 gols  % vitórias por 3+ gols
# 0   1930     18       0.00                 27.78                  16.67                   55.56
# 1   1934     17       5.88                 64.71                  17.65                   11.76
# 2   1938     18      16.67                 27.78                  33.33                   22.22
# 3   1950     22      13.64                 27.27                  27.27                   31.82
# 4   1954     26       7.69                 19.23                  30.77                   42.31
# 5   1958     35      28.57                 28.57                  17.14                   25.71
# 6   1962     32      15.62                 37.50                  37.50                    9.38
# 7   1966     32      15.62                 37.50                  34.38                   12.50
# 8   1970     32      15.62                 43.75                  15.62                   25.00
# 9   1974     38      26.32                 31.58                  21.05                   21.05
# 10  1978     38      23.68                 39.47                  21.05                   15.79
# 11  1982     52      32.69                 32.69                  13.46                   21.15
# 12  1986     52      26.92                 34.62                  21.15                   17.31
# 13  1990     52      23.08                 50.00                  15.38                   11.54
# 14  1994     52      21.15                 46.15                  17.31                   15.38
# 15  1998     64      29.69                 40.62                  10.94                   18.75
# 16  2002     64      25.00                 42.19                  21.88                   10.94
# 17  2006     64      23.44                 32.81                  29.69                   14.06
# 18  2010     64      25.00                 48.44                  14.06                   12.50
# 19  2014     64      20.31                 45.31                  15.62                   18.75
# 20  2018     64      20.31                 48.44                  18.75                   12.50
# 21  2022     64      23.44                 37.50                  25.00                   14.06

# %%
tabela_print = tabela_final.copy()

# se quiser remover a coluna de jogos na exibição (opcional)
# tabela_print = tabela_print.drop(columns=["jogos"])

tabela_print["copa"] = tabela_print["copa"].astype("Int64")

cols_pct = ["% empates", "% vitórias por 1 gol", "% vitórias por 2 gols", "% vitórias por 3+ gols"]

fmt = {col: "{:.2f}%" for col in cols_pct}
fmt["copa"] = "{:d}"

(
    tabela_print.style
        .format(fmt)
        .background_gradient(subset=["% vitórias por 1 gol"], cmap="Greens")
        .background_gradient(subset=["% vitórias por 3+ gols"], cmap="Reds")
        .hide(axis="index")
)
# Out:
# <style type="text/css">
# #T_2b484_row0_col3, #T_2b484_row2_col3 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_2b484_row0_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_2b484_row1_col3 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_2b484_row1_col5 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_2b484_row2_col5 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_2b484_row3_col3 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_2b484_row3_col5 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_2b484_row4_col3 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_2b484_row4_col5 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_2b484_row5_col3 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_2b484_row5_col5 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_2b484_row6_col3, #T_2b484_row7_col3, #T_2b484_row21_col3 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_2b484_row6_col5 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_2b484_row7_col5, #T_2b484_row18_col5, #T_2b484_row20_col5 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_2b484_row8_col3 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_2b484_row8_col5 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_2b484_row9_col3 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_2b484_row9_col5 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_2b484_row10_col3 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_2b484_row10_col5 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_2b484_row11_col3 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_2b484_row11_col5 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_2b484_row12_col3 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_2b484_row12_col5 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_2b484_row13_col3 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_2b484_row13_col5 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_2b484_row14_col3 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_2b484_row14_col5 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_2b484_row15_col3 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_2b484_row15_col5, #T_2b484_row19_col5 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_2b484_row16_col3 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_2b484_row16_col5 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_2b484_row17_col3 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_2b484_row17_col5, #T_2b484_row21_col5 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_2b484_row18_col3, #T_2b484_row20_col3 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_2b484_row19_col3 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2b484">
#   <thead>
#     <tr>
#       <th id="T_2b484_level0_col0" class="col_heading level0 col0" >copa</th>
#       <th id="T_2b484_level0_col1" class="col_heading level0 col1" >jogos</th>
#       <th id="T_2b484_level0_col2" class="col_heading level0 col2" >% empates</th>
#       <th id="T_2b484_level0_col3" class="col_heading level0 col3" >% vitórias por 1 gol</th>
#       <th id="T_2b484_level0_col4" class="col_heading level0 col4" >% vitórias por 2 gols</th>
#       <th id="T_2b484_level0_col5" class="col_heading level0 col5" >% vitórias por 3+ gols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_2b484_row0_col0" class="data row0 col0" >1930</td>
#       <td id="T_2b484_row0_col1" class="data row0 col1" >18</td>
#       <td id="T_2b484_row0_col2" class="data row0 col2" >0.00%</td>
#       <td id="T_2b484_row0_col3" class="data row0 col3" >27.78%</td>
#       <td id="T_2b484_row0_col4" class="data row0 col4" >16.67%</td>
#       <td id="T_2b484_row0_col5" class="data row0 col5" >55.56%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row1_col0" class="data row1 col0" >1934</td>
#       <td id="T_2b484_row1_col1" class="data row1 col1" >17</td>
#       <td id="T_2b484_row1_col2" class="data row1 col2" >5.88%</td>
#       <td id="T_2b484_row1_col3" class="data row1 col3" >64.71%</td>
#       <td id="T_2b484_row1_col4" class="data row1 col4" >17.65%</td>
#       <td id="T_2b484_row1_col5" class="data row1 col5" >11.76%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row2_col0" class="data row2 col0" >1938</td>
#       <td id="T_2b484_row2_col1" class="data row2 col1" >18</td>
#       <td id="T_2b484_row2_col2" class="data row2 col2" >16.67%</td>
#       <td id="T_2b484_row2_col3" class="data row2 col3" >27.78%</td>
#       <td id="T_2b484_row2_col4" class="data row2 col4" >33.33%</td>
#       <td id="T_2b484_row2_col5" class="data row2 col5" >22.22%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row3_col0" class="data row3 col0" >1950</td>
#       <td id="T_2b484_row3_col1" class="data row3 col1" >22</td>
#       <td id="T_2b484_row3_col2" class="data row3 col2" >13.64%</td>
#       <td id="T_2b484_row3_col3" class="data row3 col3" >27.27%</td>
#       <td id="T_2b484_row3_col4" class="data row3 col4" >27.27%</td>
#       <td id="T_2b484_row3_col5" class="data row3 col5" >31.82%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row4_col0" class="data row4 col0" >1954</td>
#       <td id="T_2b484_row4_col1" class="data row4 col1" >26</td>
#       <td id="T_2b484_row4_col2" class="data row4 col2" >7.69%</td>
#       <td id="T_2b484_row4_col3" class="data row4 col3" >19.23%</td>
#       <td id="T_2b484_row4_col4" class="data row4 col4" >30.77%</td>
#       <td id="T_2b484_row4_col5" class="data row4 col5" >42.31%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row5_col0" class="data row5 col0" >1958</td>
#       <td id="T_2b484_row5_col1" class="data row5 col1" >35</td>
#       <td id="T_2b484_row5_col2" class="data row5 col2" >28.57%</td>
#       <td id="T_2b484_row5_col3" class="data row5 col3" >28.57%</td>
#       <td id="T_2b484_row5_col4" class="data row5 col4" >17.14%</td>
#       <td id="T_2b484_row5_col5" class="data row5 col5" >25.71%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row6_col0" class="data row6 col0" >1962</td>
#       <td id="T_2b484_row6_col1" class="data row6 col1" >32</td>
#       <td id="T_2b484_row6_col2" class="data row6 col2" >15.62%</td>
#       <td id="T_2b484_row6_col3" class="data row6 col3" >37.50%</td>
#       <td id="T_2b484_row6_col4" class="data row6 col4" >37.50%</td>
#       <td id="T_2b484_row6_col5" class="data row6 col5" >9.38%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row7_col0" class="data row7 col0" >1966</td>
#       <td id="T_2b484_row7_col1" class="data row7 col1" >32</td>
#       <td id="T_2b484_row7_col2" class="data row7 col2" >15.62%</td>
#       <td id="T_2b484_row7_col3" class="data row7 col3" >37.50%</td>
#       <td id="T_2b484_row7_col4" class="data row7 col4" >34.38%</td>
#       <td id="T_2b484_row7_col5" class="data row7 col5" >12.50%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row8_col0" class="data row8 col0" >1970</td>
#       <td id="T_2b484_row8_col1" class="data row8 col1" >32</td>
#       <td id="T_2b484_row8_col2" class="data row8 col2" >15.62%</td>
#       <td id="T_2b484_row8_col3" class="data row8 col3" >43.75%</td>
#       <td id="T_2b484_row8_col4" class="data row8 col4" >15.62%</td>
#       <td id="T_2b484_row8_col5" class="data row8 col5" >25.00%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row9_col0" class="data row9 col0" >1974</td>
#       <td id="T_2b484_row9_col1" class="data row9 col1" >38</td>
#       <td id="T_2b484_row9_col2" class="data row9 col2" >26.32%</td>
#       <td id="T_2b484_row9_col3" class="data row9 col3" >31.58%</td>
#       <td id="T_2b484_row9_col4" class="data row9 col4" >21.05%</td>
#       <td id="T_2b484_row9_col5" class="data row9 col5" >21.05%</td>
#     </tr>
#     <tr>
#       <td id="T_2b484_row10_col0" class="data row10 col0" >1978</td>
#       <td id="T_2b484_row10_col1" class="data row10 col1" >38</td>
#       <td id="T_2b484_row10_col2" class="data row10 col2" >23.68%</td>
#       <td id="T_2b484_row10_col3" class="data row10 col3" >39.47%</td>
#       <td id="T_2b484_row10_col4" class="data row10 col4" >21.05%</td>
#       <td id="T_2b484_row10_col5" class="da

# %%
# copas_chave = [1930, 1954, 1970, 1990, 1998, 2014, 2022]
tabela_print = tabela_final.copy()

tabela_print = tabela_print.drop(columns=["jogos"])
tabela_print["copa"] = tabela_print["copa"].astype("Int64")

col_verde = "% vitórias por 1 gol"
col_vermelho = "% vitórias por 3+ gols"

fmt = {col: "{:.2f}" for col in tabela_print.columns if col != "copa"}
fmt["copa"] = "{:d}"

(
    tabela_print.style
      .format(fmt)  # <- aqui resolve o .00 da copa
      .background_gradient(subset=[col_verde], cmap="Greens")
      .background_gradient(subset=[col_vermelho], cmap="Reds")
      .hide(axis="index")
)
# Out:
# <style type="text/css">
# #T_e5b9e_row0_col2, #T_e5b9e_row2_col2 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_e5b9e_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_e5b9e_row1_col2 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e5b9e_row1_col4 {
#   background-color: #ffece4;
#   color: #000000;
# }
# #T_e5b9e_row2_col4 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_e5b9e_row3_col2 {
#   background-color: #d9f0d3;
#   color: #000000;
# }
# #T_e5b9e_row3_col4 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_e5b9e_row4_col2 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_e5b9e_row4_col4 {
#   background-color: #d52221;
#   color: #f1f1f1;
# }
# #T_e5b9e_row5_col2 {
#   background-color: #d2edcc;
#   color: #000000;
# }
# #T_e5b9e_row5_col4 {
#   background-color: #fc997a;
#   color: #000000;
# }
# #T_e5b9e_row6_col2, #T_e5b9e_row7_col2, #T_e5b9e_row21_col2 {
#   background-color: #98d594;
#   color: #000000;
# }
# #T_e5b9e_row6_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_e5b9e_row7_col4, #T_e5b9e_row18_col4, #T_e5b9e_row20_col4 {
#   background-color: #feeae0;
#   color: #000000;
# }
# #T_e5b9e_row8_col2 {
#   background-color: #63bc6e;
#   color: #f1f1f1;
# }
# #T_e5b9e_row8_col4 {
#   background-color: #fc9e80;
#   color: #000000;
# }
# #T_e5b9e_row9_col2 {
#   background-color: #c1e6ba;
#   color: #000000;
# }
# #T_e5b9e_row9_col4 {
#   background-color: #fcbba1;
#   color: #000000;
# }
# #T_e5b9e_row10_col2 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_e5b9e_row10_col4 {
#   background-color: #fedccd;
#   color: #000000;
# }
# #T_e5b9e_row11_col2 {
#   background-color: #bae3b3;
#   color: #000000;
# }
# #T_e5b9e_row11_col4 {
#   background-color: #fcb99f;
#   color: #000000;
# }
# #T_e5b9e_row12_col2 {
#   background-color: #acdea6;
#   color: #000000;
# }
# #T_e5b9e_row12_col4 {
#   background-color: #fdd3c1;
#   color: #000000;
# }
# #T_e5b9e_row13_col2 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_e5b9e_row13_col4 {
#   background-color: #ffeee6;
#   color: #000000;
# }
# #T_e5b9e_row14_col2 {
#   background-color: #4eb264;
#   color: #f1f1f1;
# }
# #T_e5b9e_row14_col4 {
#   background-color: #fedfd0;
#   color: #000000;
# }
# #T_e5b9e_row15_col2 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_e5b9e_row15_col4, #T_e5b9e_row19_col4 {
#   background-color: #fdcab5;
#   color: #000000;
# }
# #T_e5b9e_row16_col2 {
#   background-color: #72c375;
#   color: #000000;
# }
# #T_e5b9e_row16_col4 {
#   background-color: #fff0e8;
#   color: #000000;
# }
# #T_e5b9e_row17_col2 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_e5b9e_row17_col4, #T_e5b9e_row21_col4 {
#   background-color: #fee5d8;
#   color: #000000;
# }
# #T_e5b9e_row18_col2, #T_e5b9e_row20_col2 {
#   background-color: #3da65a;
#   color: #f1f1f1;
# }
# #T_e5b9e_row19_col2 {
#   background-color: #56b567;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_e5b9e">
#   <thead>
#     <tr>
#       <th id="T_e5b9e_level0_col0" class="col_heading level0 col0" >copa</th>
#       <th id="T_e5b9e_level0_col1" class="col_heading level0 col1" >% empates</th>
#       <th id="T_e5b9e_level0_col2" class="col_heading level0 col2" >% vitórias por 1 gol</th>
#       <th id="T_e5b9e_level0_col3" class="col_heading level0 col3" >% vitórias por 2 gols</th>
#       <th id="T_e5b9e_level0_col4" class="col_heading level0 col4" >% vitórias por 3+ gols</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_e5b9e_row0_col0" class="data row0 col0" >1930</td>
#       <td id="T_e5b9e_row0_col1" class="data row0 col1" >0.00</td>
#       <td id="T_e5b9e_row0_col2" class="data row0 col2" >27.78</td>
#       <td id="T_e5b9e_row0_col3" class="data row0 col3" >16.67</td>
#       <td id="T_e5b9e_row0_col4" class="data row0 col4" >55.56</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row1_col0" class="data row1 col0" >1934</td>
#       <td id="T_e5b9e_row1_col1" class="data row1 col1" >5.88</td>
#       <td id="T_e5b9e_row1_col2" class="data row1 col2" >64.71</td>
#       <td id="T_e5b9e_row1_col3" class="data row1 col3" >17.65</td>
#       <td id="T_e5b9e_row1_col4" class="data row1 col4" >11.76</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row2_col0" class="data row2 col0" >1938</td>
#       <td id="T_e5b9e_row2_col1" class="data row2 col1" >16.67</td>
#       <td id="T_e5b9e_row2_col2" class="data row2 col2" >27.78</td>
#       <td id="T_e5b9e_row2_col3" class="data row2 col3" >33.33</td>
#       <td id="T_e5b9e_row2_col4" class="data row2 col4" >22.22</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row3_col0" class="data row3 col0" >1950</td>
#       <td id="T_e5b9e_row3_col1" class="data row3 col1" >13.64</td>
#       <td id="T_e5b9e_row3_col2" class="data row3 col2" >27.27</td>
#       <td id="T_e5b9e_row3_col3" class="data row3 col3" >27.27</td>
#       <td id="T_e5b9e_row3_col4" class="data row3 col4" >31.82</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row4_col0" class="data row4 col0" >1954</td>
#       <td id="T_e5b9e_row4_col1" class="data row4 col1" >7.69</td>
#       <td id="T_e5b9e_row4_col2" class="data row4 col2" >19.23</td>
#       <td id="T_e5b9e_row4_col3" class="data row4 col3" >30.77</td>
#       <td id="T_e5b9e_row4_col4" class="data row4 col4" >42.31</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row5_col0" class="data row5 col0" >1958</td>
#       <td id="T_e5b9e_row5_col1" class="data row5 col1" >28.57</td>
#       <td id="T_e5b9e_row5_col2" class="data row5 col2" >28.57</td>
#       <td id="T_e5b9e_row5_col3" class="data row5 col3" >17.14</td>
#       <td id="T_e5b9e_row5_col4" class="data row5 col4" >25.71</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row6_col0" class="data row6 col0" >1962</td>
#       <td id="T_e5b9e_row6_col1" class="data row6 col1" >15.62</td>
#       <td id="T_e5b9e_row6_col2" class="data row6 col2" >37.50</td>
#       <td id="T_e5b9e_row6_col3" class="data row6 col3" >37.50</td>
#       <td id="T_e5b9e_row6_col4" class="data row6 col4" >9.38</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row7_col0" class="data row7 col0" >1966</td>
#       <td id="T_e5b9e_row7_col1" class="data row7 col1" >15.62</td>
#       <td id="T_e5b9e_row7_col2" class="data row7 col2" >37.50</td>
#       <td id="T_e5b9e_row7_col3" class="data row7 col3" >34.38</td>
#       <td id="T_e5b9e_row7_col4" class="data row7 col4" >12.50</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row8_col0" class="data row8 col0" >1970</td>
#       <td id="T_e5b9e_row8_col1" class="data row8 col1" >15.62</td>
#       <td id="T_e5b9e_row8_col2" class="data row8 col2" >43.75</td>
#       <td id="T_e5b9e_row8_col3" class="data row8 col3" >15.62</td>
#       <td id="T_e5b9e_row8_col4" class="data row8 col4" >25.00</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row9_col0" class="data row9 col0" >1974</td>
#       <td id="T_e5b9e_row9_col1" class="data row9 col1" >26.32</td>
#       <td id="T_e5b9e_row9_col2" class="data row9 col2" >31.58</td>
#       <td id="T_e5b9e_row9_col3" class="data row9 col3" >21.05</td>
#       <td id="T_e5b9e_row9_col4" class="data row9 col4" >21.05</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row10_col0" class="data row10 col0" >1978</td>
#       <td id="T_e5b9e_row10_col1" class="data row10 col1" >23.68</td>
#       <td id="T_e5b9e_row10_col2" class="data row10 col2" >39.47</td>
#       <td id="T_e5b9e_row10_col3" class="data row10 col3" >21.05</td>
#       <td id="T_e5b9e_row10_col4" class="data row10 col4" >15.79</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row11_col0" class="data row11 col0" >1982</td>
#       <td id="T_e5b9e_row11_col1" class="data row11 col1" >32.69</td>
#       <td id="T_e5b9e_row11_col2" class="data row11 col2" >32.69</td>
#       <td id="T_e5b9e_row11_col3" class="data row11 col3" >13.46</td>
#       <td id="T_e5b9e_row11_col4" class="data row11 col4" >21.15</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row12_col0" class="data row12 col0" >1986</td>
#       <td id="T_e5b9e_row12_col1" class="data row12 col1" >26.92</td>
#       <td id="T_e5b9e_row12_col2" class="data row12 col2" >34.62</td>
#       <td id="T_e5b9e_row12_col3" class="data row12 col3" >21.15</td>
#       <td id="T_e5b9e_row12_col4" class="data row12 col4" >17.31</td>
#     </tr>
#     <tr>
#       <td id="T_e5b9e_row13_col0" class="data row13 col0"
